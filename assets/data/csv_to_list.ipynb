# %%
import pandas as pd

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
cities_file = "cities.csv"
cities_df = pd.read_csv(cities_file)
cities_df
# Out:
#            City  Temperature (F)  Humidity (%)  Clouds(% Cloudy)  \
# 0      berlevag            24.58            74                75
# 1       ushuaia            62.60            55                75
# 2         vaini            78.80            89                75
# 3       mataura            67.14            50                98
# 4    butaritari            81.28            80                93
# ..          ...              ...           ...               ...
# 548   tazovskiy            -8.91            91               100
# 549     andenes            32.00            69                75
# 550      senovo            49.57            76                90
# 551         obo            65.97            26                73
# 552      panaba            84.88            60                 6
#
#      Windspeed (mph)  Latitude  Longitude Country   Date-Time
# 0              25.32   70.8578    29.0864      NO  1612733639
# ...

# %%
cities_to_html = cities_df.to_html()
print(cities_to_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Temperature (F)</th>
#       <th>Humidity (%)</th>
#       <th>Clouds(% Cloudy)</th>
#       <th>Windspeed (mph)</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Country</th>
#       <th>Date-Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>berlevag</td>
#       <td>24.58</td>
#       <td>74</td>
#       <td>75</td>
#       <td>25.32</td>
#       <td>70.8578</td>
#       <td>29.0864</td>
#       <td>NO</td>
#       <td>1612733639</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ushuaia</td>
#       <td>62.60</td>
#       <td>55</td>
#       <td>75</td>
#       <td>6.91</td>
#       <td>-54.8000</td>
#       <td>-68.3000</td>
#       <td>AR</td>
#       <td>1612733485</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>vaini</td>
#       <td>78.80</td>
# ...
